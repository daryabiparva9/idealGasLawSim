# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(0.01, 2, 20)
y = ( 1 - 2 * np.exp(-1 * t))/( 1 - np.exp(-1 * t))
plt.plot(t, y)

# %%
y
# Out:
# array([-9.85008333e+01, -7.22515564e+00, -3.07462972e+00, -1.61138592e+00,
#        -8.66924818e-01, -4.18031248e-01, -1.19208211e-01,  9.30237636e-02,
#         2.50782816e-01,  3.72065631e-01,  4.67741194e-01,  5.44762584e-01,
#         6.07785536e-01,  6.60045407e-01,  7.03860848e-01,  7.40937272e-01,
#         7.72557198e-01,  7.99703788e-01,  8.23143427e-01,  8.43482357e-01])
